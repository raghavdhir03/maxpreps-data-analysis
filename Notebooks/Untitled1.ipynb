# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/rdhir/Documents/Research_Project/Notebooks'

# %%
os.chdir('/Users/rdhir/Documents/Research_Project/Data')

# %%
ls
# Out:
# Demographics.csv           private_school_subset.csv
# MaxPreps.csv               private_schools.csv
# States/                    public_schools.csv
# Team1_subset.csv           public_schools1.csv
# agency_id.csv              regression_subset.csv
# finance.csv                summary_stats.csv
# maxpreps_and_demo.csv      summary_stats.txt

# %%
df = pd.read_csv("maxpreps_and_demo.csv")
# Out:
# /var/folders/vl/lnfg4f0d5872pfxx4dys19km0000gn/T/ipykernel_16102/2485282288.py:1: DtypeWarning: Columns (35,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("maxpreps_and_demo.csv")

# %%
df[(df['Team 1'] == 'Bowie') & (df['Team 1 City'] == 'Austin')]
# Out:
#        Unnamed: 0   Date Team 1        Team 2 Venue       Game Type  \
# 85336       85336  11/13  Bowie       Johnson     H  Regular Season
# 85337       85337  11/20  Bowie      Lockhart     A  Regular Season
# 85338       85338  11/22  Bowie        McNeil     H  Regular Season
# 85339       85339   12/2  Bowie    Round Rock     H  Regular Season
# 85340       85340   12/2  Bowie    University     H      Tournament
# 85341       85341   12/3  Bowie      Crockett     H      Tournament
# 85342       85342   12/4  Bowie    LBJ Austin     H      Tournament
# 85343       85343   12/4  Bowie    Round Rock     H  Regular Season
# 85344       85344   12/7  Bowie    Round Rock     H  Regular Season
# 85345       85345   12/9  Bowie         Glenn     H      Tournament
# 85346       85346   12/9  Bowie    Clear Lake     H      Tournament
# 85347       85347  12/10  Bowie  Pflugerville     A      Tournament
# 85348       85348  12/10  Bowie   Cedar Ridge     A      Tournament
# ...

# %%
df.iloc[85350]
# Out:
# Unnamed: 0                                                                            85350
# Date                                                                                  12/21
# Team 1                                                                                Bowie
# Team 2                                                                             Westlake
# Venue                                                                                     H
# Game Type                                                                          District
# Team 1 Score                                                                           31.0
# Team 2 Score                                                                           67.0
# Outcome                                                                                   L
# Team 1 Address                                                          4103 Slaughter Ln W
# ...
