# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/rdhir/Documents/Research_Project/Notebooks'

# %%
os.chdir('/Users/rdhir/Documents/Research_Project/Data')

# %%
df = pd.read_csv('Team1_Subset.csv')

# %%
private_school_subset = df[df['T1 Private School'] == 1]

# %%
private_school_subset
# Out:
#        Unnamed: 0                     Team 1  Team 1 Label  num boys Sports  \
# 3              74     Academy of Holy Angels             4              7.0
# 34            956          Bethlehem Academy            35              5.0
# 43           1200                      Breck            44              7.0
# 82           2305                     Cotter            83              5.0
# 92           2589                  DeLaSalle            93              5.0
# ...           ...                        ...           ...              ...
# 19501      466514        Loyola-Sacred Heart         19502              5.0
# 19503      466552           Lustre Christian         19504              3.0
# 19540      467263  St. Labre Indian Catholic         19541              6.0
# 19548      467415       Stillwater Christian         19549              3.0
# 19557      467588           Valley Christian         19558              5.0
#
# ...

# %%
private_school_subset.drop(columns = ['T1 Free and Reduced Lunch', 'T1 Expenditures/Pupil'], inplace = True)
# Out:
# /var/folders/vl/lnfg4f0d5872pfxx4dys19km0000gn/T/ipykernel_93898/1734675397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   private_school_subset.drop(columns = ['T1 Free and Reduced Lunch', 'T1 Expenditures/Pupil'], inplace = True)

# %%
private_school_subset.drop(columns = 'Unnamed: 0', inplace = True)
# Out:
# /var/folders/vl/lnfg4f0d5872pfxx4dys19km0000gn/T/ipykernel_93898/3590638207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   private_school_subset.drop(columns = 'Unnamed: 0', inplace = True)

# %%
private_school_subset.to_csv('private_school_subset.csv')

# %%
private_school_subset
# Out:
#                           Team 1  Team 1 Label  num boys Sports  \
# 3         Academy of Holy Angels             4              7.0
# 34             Bethlehem Academy            35              5.0
# 43                         Breck            44              7.0
# 82                        Cotter            83              5.0
# 92                     DeLaSalle            93              5.0
# ...                          ...           ...              ...
# 19501        Loyola-Sacred Heart         19502              5.0
# 19503           Lustre Christian         19504              3.0
# 19540  St. Labre Indian Catholic         19541              6.0
# 19548       Stillwater Christian         19549              3.0
# 19557           Valley Christian         19558              5.0
#
#        T1 American Indian/Alaska Native  T1 Asian or Asian/Pacific Islander  \
# 3                                   NaN                                 NaN
# ...

# %%
ls
# Out:
# Demographics.csv           private_school_subset.csv
# MaxPreps.csv               private_schools.csv
# States/                    public_schools.csv
# Team1_subset.csv           public_schools1.csv
# agency_id.csv              regression_subset.csv
# finance.csv                summary_stats.csv
# maxpreps_and_demo.csv      summary_stats.txt

# %%
data = pd.read_csv('maxpreps_and_demo.csv')
# Out:
# /var/folders/vl/lnfg4f0d5872pfxx4dys19km0000gn/T/ipykernel_93898/2778916154.py:1: DtypeWarning: Columns (35,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('maxpreps_and_demo.csv')

# %%
data[data['T1 Black']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 data[data['T1 Black']]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
# ...
