# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.maxpreps.com/tx/duncanville/duncanville-panthers-and-pantherettes/basketball/21-22/schedule/'
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')

# %%
table = soup.find('table')

# %%
data = pd.read_html(str(table))[0]

# %% [markdown]
# ### Making a Dictionary for each state where the keys are the school name and the values are the URL

# %%
url1 = 'https://www.maxpreps.com/basketball/21-22/rankings/1/'
response = requests.get(url1).text
soup = BeautifulSoup(response, 'html.parser')

# %%
#Creating a list that contains the name of each school
school_elements = soup.find_all('th', class_='school')

#Creating another list that contains the URL for each high school
school_links = []
for school in school_elements:
    school_links.append(school.find('a'))

# %%
school_elements.pop(0)
school_links.pop(0)
for i in range(len(school_elements)):
    school_elements[i] = school_elements[i].text
    school_links[i] = school_links[i].get('href')

# %%
school_dict = dict(zip(school_elements, school_links))

# %%
school_dict
# Out:
# {'Duncanville': '/tx/duncanville/duncanville-panthers-and-pantherettes/basketball/21-22/schedule/',
#  'Centennial (Corona)': '/ca/corona/centennial-huskies/basketball/21-22/schedule/',
#  'Calvary Christian Academy (Fort Lauderdale)': '/fl/fort-lauderdale/calvary-christian-academy-eagles/basketball/21-22/schedule/',
#  'Roselle Catholic (Roselle)': '/nj/roselle/roselle-catholic-lions/basketball/21-22/schedule/',
#  'North Little Rock': '/ar/north-little-rock/north-little-rock-charging-wildcats/basketball/21-22/schedule/',
#  'Glenbard West (Glen Ellyn)': '/il/glen-ellyn/glenbard-west-hilltoppers/basketball/21-22/schedule/',
#  'Cardinal Hayes (Bronx)': '/ny/bronx/cardinal-hayes-cardinals/basketball/21-22/schedule/',
#  'Richardson': '/tx/richardson/richardson-eagles/basketball/21-22/schedule/',
#  'Camden': '/nj/camden/camden-panthers/basketball/21-22/schedule/',
#  'Paul VI (Chantilly)': '/va/chantilly/st-paul-vi-panthers/basketball/21-22/schedule/',
#  'Imhotep Charter (Philadelphia)': '/pa/philadelphia/imhotep-charter-panthers/basketball/21-22/schedule/',
#  'Weddington (Matthews)': '/nc/matthews/weddington-warriors/basketball/21-22/schedule/',
#  'Archbishop Stepinac (White Plains)': '/ny/white-plains/archbishop-stepinac-crusaders/basketball/21-22/schedule/',
#  'Carmel Christian (Matthews)': '/nc/matthews/carmel-christian-cougars/basketball/21-22/schedule/',
#  'Christian Brothers (Memphis)': '/tn/memphis/christian-brothers-purple-wave/basketball/21-22/schedule/',
#  'George Rogers Clark (Winchester)': '/ky/winchester/george-rogers-clark-cardinals/basketball/21-22/schedule/',
#  'Beaumont United (Beaumont)': '/tx/beaumont/beaumont-united-timberwolves/basketball/21-22/schedule/',
#  'Columbus (Miami)': '/fl/miami/columbus-explorers/basketball/21-22/schedule/',
#  'Jonesboro': '/ar/jonesboro/jonesboro-hurricane/basketball/21-22/schedule/',
#  'Sidwell Friends (Washington)': '/dc/washington/sidwell-friends-quakers/basketball/21-22/schedule/',
#  'Auburn': '/wa/auburn/auburn-trojans/basketball/21-22/schedule/',
#  'Pickerington Central (Pickerington)': '/oh/pickerington/pickerington-central-tigers/basketball/21-22/schedule/',
#  'Bishop Gorman (Las Vegas)': '/nv/las-vegas/bishop-gorman-gaels/basketball/21-22/schedule/',
#  'Centerville': '/oh/centerville/centerville-elks/basketball/21-22/schedule/',
#  'Liberty (Henderson)': '/nv/henderson/liberty-patriots/basketball/21-22/schedule/'}

# %% [markdown]
# ## PRACCY

# %%
school_dict = {'Duncanville': '/tx/duncanville/duncanville-panthers-and-pantherettes/basketball/21-22/schedule/'}
school = 'Duncanville'
url = 'https://www.maxpreps.com{}'.format(school_dict[school])
    
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')

table = soup.find('table')
if table:
    # Convert the table to DataFrame
    data = pd.read_html(str(table))[0]
    data['Team 1'] = school
    data = data.drop('Game Info', axis = 1)
    
else:
    print(f"No table found on {url}")

# %%
data
# Out:
#      Date                        Opponent       Result       Team 1
# 0   11/12                  vsShadow Creek       W89-38  Duncanville
# 1   11/13                     vsLancaster      W102-59  Duncanville
# 2   11/20                       vsKimball       W84-82  Duncanville
# 3   11/24                       vsWheeler       W80-58  Duncanville
# 4   11/26                    vsCentennial       W75-70  Duncanville
# 5   11/27                 vsSierra Canyon       W80-73  Duncanville
# 6   11/30                      @Rock Hill       W90-66  Duncanville
# 7    12/3                    vsZachary***       W86-56  Duncanville
# 8    12/4  vsCarver Collegiate Academy***       W93-52  Duncanville
# 9    12/9             vsMontverde Academy       W67-66  Duncanville
# 10  12/11                 vsAmerican Fork       W79-66  Duncanville
# 11  12/21                        @DeSoto*       W57-51  Duncanville
# 12  12/28                 vsSt. Mark's***       W81-43  Duncanville
# 13  12/29                     vsMartin***       W61-55  Duncanville
# 14  12/29       vsMansfield Timberview***       W83-49  Duncanville
# 15  12/30                 vsRichardson***  L60-58 (OT)  Duncanville
# 16    1/4                       vsMidway*       W54-42  Duncanville
# 17    1/7                    @Lake Ridge*       W71-55  Duncanville
# 18   1/11                   vsWaxahachie*       W77-52  Duncanville
# 19   1/14                    @Cedar Hill*      W106-85  Duncanville
# 20   1/18                     @Mansfield*       W73-31  Duncanville
# 21   1/21                         vsWaco*       W85-42  Duncanville
# 22   1/25                       vsDeSoto*       W76-56  Duncanville
# 23   1/28                        @Midway*       W61-42  Duncanville
# 24    2/1                   vsLake Ridge*       W71-63  Duncanville
# 25    2/4                    @Waxahachie*       W91-50  Duncanville
# 26    2/8                   vsCedar Hill*       W95-50  Duncanville
# 27   2/11                    vsMansfield*       W74-39  Duncanville
# 28   2/15                          @Waco*      W105-32  Duncanville
# 29   2/22                   vsShoemaker**       W99-63  Duncanville
# 30   2/25                 @Rockwall-Heath       W52-43  Duncanville
# 31    3/1                       vsDeSoto*       W48-35  Duncanville
# 32    3/4               vsCypress Ranch**       W72-59  Duncanville
# 33    3/5                     vsGarland**       W61-38  Duncanville
# 34   3/11                    vsAtascocita       W50-36  Duncanville
# 35   3/12                    vsMcKinney**       W69-49  Duncanville

# %% [markdown]
# #### Extracting Location Data

# %%
def extractLocation(school):
    url = 'https://www.maxpreps.com{}'.format(school)
    #print(url)
    # Make a request to the webpage
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the address element
        address_element = soup.select_one('address') 
        #print(address_element)
        # Exclude the text within the span within the address element
        if address_element:
            city_state = address_element.find('span')
    
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return None  # Return None or some default value if the request fails

    return city_state.text

# %%
def extractAddress(school):
    url = 'https://www.maxpreps.com{}'.format(school)

    # Make a request to the webpage
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the address element
        address_element = soup.select_one('address') 
        #print(address_element)
        # Exclude the text within the span within the address element
        if address_element:
            city_state = address_element.find('span')
            city_state.decompose()

            address_text = address_element.get_text(strip=True)
        else:
            print("No address element found.")
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        
    return address_text

# %%
# get list of the URLS for Team 2

team_2_elements = soup.find_all('a', class_='raRFl')
team_2_links = []
for element in team_2_elements:
    link = element.get('href')
    link = link[24:]
    team_2_links.append(link)

# %%
team_2_locations = []
team_2_addresses = []
for team in team_2_links:
    team_2_locations.append(extractLocation(team))
    team_2_addresses.append(extractAddress(team))

# %%
import concurrent.futures

with concurrent.futures.ThreadPoolExecutor() as executor:
    team_2_locations = list(executor.map(extractLocation, team_2_links))
    team_2_addresses = list(executor.map(extractAddress, team_2_links))

# %%
data['Team 2 Location'] = team_2_locations
data['Team 2 Address'] = team_2_addresses

# %% [markdown]
# #### Extracting Venue, Score, Outcome, Game Type

# %%
import re
def gameInfo(column):
    pattern = r'(?P<venue>[vs@]*)(?P<name>[a-zA-Z]+(\.|-)?\s?[a-zA-Z]*\'?\w*)(?P<type>[*]*)'
    # Apply str.extract to create new columns based on the pattern
    _venue = column.str.extract(pattern)['venue']
    _team2 = column.str.extract(pattern)['name']
    _gametype = column.str.extract(pattern)['type']
    
    
    return (_venue, _team2, _gametype)

# %%
def cleanGameType(string):
    #string = str(len(string))
    if len(string) == 3:
        string = 'Tournament'
    elif len(string) == 2:
        string = 'Playoff'
    elif len(string) == 1:
        string = 'District'
    else:
        string = 'Regular Season'
    return string

# %%
def cleanVenueType(string):
    if string == '@':
        return 'A'
    return 'H'

# %%
def scoreInfo(column):
    pattern = r'(?P<Outcome>[WL]?)(?P<Team_1_Score>\d+)-(?P<Team_2_Score>\d+)'
    
    _outcome = column.str.extract(pattern)['Outcome']
    _t1score = column.str.extract(pattern)['Team_1_Score']
    _t2score = column.str.extract(pattern)['Team_2_Score']
    
    return (_outcome, _t1score, _t2score)

# %%
def splitLocation(column):
    
    pattern = r'(?P<city>[^,]+).\s?(?P<state>\w\w)\s?(?P<zipcode>\d\d\d\d\d)'

    _city = column.str.extract(pattern)['city']
    _state = column.str.extract(pattern)['state']
    _zip = column.str.extract(pattern)['zipcode']
    
    return (_city, _state, _zip)

# %%
data['Team 1 Location'] = extractLocation(school_dict['Duncanville'])
data['Team 1 Address'] = extractAddress(school_dict['Duncanville'])
data['Team 1 City'] = splitLocation(data['Team 1 Location'])[0]
data['Team 1 State'] = splitLocation(data['Team 1 Location'])[1]
data['Team 1 Zipcode'] = splitLocation(data['Team 1 Location'])[2]
data['Team 2 City'] = splitLocation(data['Team 2 Location'])[0]
data['Team 2 State'] = splitLocation(data['Team 2 Location'])[1]
data['Team 2 Zipcode'] = splitLocation(data['Team 2 Location'])[2]
data['Venue'] = gameInfo(data['Opponent'])[0].apply(cleanVenueType)
data['Team 2'] = gameInfo(data['Opponent'])[1]
data['Game Type'] = gameInfo(data['Opponent'])[2].apply(cleanGameType)
data['Outcome'] = scoreInfo(data['Result'])[0]
data['Team 1 Score'] = scoreInfo(data['Result'])[1]
data['Team 2 Score'] = scoreInfo(data['Result'])[2]

# %%
data.columns
# Out:
# Index(['Date', 'Opponent', 'Result', 'Team 1', 'Team 2 Location',
#        'Team 2 Address', 'Team 1 Location', 'Team 1 Address', 'Team 1 City',
#        'Team 1 State', 'Team 1 Zipcode', 'Team 2 City', 'Team 2 State',
#        'Team 2 Zipcode', 'Venue', 'Team 2', 'Game Type', 'Outcome',
#        'Team 1 Score', 'Team 2 Score'],
#       dtype='object')

# %%
cols = ['Date', 'Team 1', 'Team 2', 'Venue', 'Game Type',
       'Team 1 Score', 'Team 2 Score', 'Outcome', 'Team 1 Address', 'Team 1 City',
       'Team 1 State', 'Team 1 Zipcode', 'Team 2 Address',
        'Team 2 City', 'Team 2 State', 'Team 2 Zipcode']

# %%
data = data[cols]

# %%
data
# Out:
#      Date       Team 1                Team 2 Venue       Game Type  \
# 0   11/12  Duncanville          Shadow Creek     H  Regular Season
# 1   11/13  Duncanville             Lancaster     H  Regular Season
# 2   11/20  Duncanville               Kimball     H  Regular Season
# 3   11/24  Duncanville               Wheeler     H  Regular Season
# 4   11/26  Duncanville            Centennial     H  Regular Season
# 5   11/27  Duncanville         Sierra Canyon     H  Regular Season
# 6   11/30  Duncanville             Rock Hill     A  Regular Season
# 7    12/3  Duncanville               Zachary     H      Tournament
# 8    12/4  Duncanville     Carver Collegiate     H  Regular Season
# 9    12/9  Duncanville     Montverde Academy     H  Regular Season
# 10  12/11  Duncanville         American Fork     H  Regular Season
# 11  12/21  Duncanville                DeSoto     A        District
# 12  12/28  Duncanville            St. Mark's     H      Tournament
# 13  12/29  Duncanville                Martin     H      Tournament
# 14  12/29  Duncanville  Mansfield Timberview     H      Tournament
# 15  12/30  Duncanville            Richardson     H      Tournament
# 16    1/4  Duncanville                Midway     H        District
# 17    1/7  Duncanville            Lake Ridge     A        District
# 18   1/11  Duncanville            Waxahachie     H        District
# 19   1/14  Duncanville            Cedar Hill     A        District
# 20   1/18  Duncanville             Mansfield     A        District
# 21   1/21  Duncanville                  Waco     H        District
# 22   1/25  Duncanville                DeSoto     H        District
# 23   1/28  Duncanville                Midway     A        District
# 24    2/1  Duncanville            Lake Ridge     H        District
# 25    2/4  Duncanville            Waxahachie     A        District
# 26    2/8  Duncanville            Cedar Hill     H        District
# 27   2/11  Duncanville             Mansfield     H        District
# 28   2/15  Duncanville                  Waco     A        District
# 29   2/22  Duncanville             Shoemaker     H         Playoff
# 30   2/25  Duncanville        Rockwall-Heath     A  Regular Season
# 31    3/1  Duncanville                DeSoto     H        District
# 32    3/4  Duncanville         Cypress Ranch     H         Playoff
# 33    3/5  Duncanville               Garland     H         Playoff
# 34   3/11  Duncanville            Atascocita     H  Regular Season
# 35   3/12  Duncanville              McKinney     H         Playoff
#
#    Team 1 Score Team 2 Score Outcome        Team 1 Address  Team 1 City  \
# 0            89           38       W  900 W Camp Wisdom Rd  Duncanville
# 1           102           59       W  900 W Camp Wisdom Rd  Duncanville
# 2            84           82       W  900 W Camp Wisdom Rd  Duncanville
# 3            80           58       W  900 W Camp Wisdom Rd  Duncanville
# 4            75           70       W  900 W Camp Wisdom Rd  Duncanville
# 5            80           73       W  900 W Camp Wisdom Rd  Duncanville
# 6            90           66       W  900 W Camp Wisdom Rd  Duncanville
# 7            86           56       W  900 W Camp Wisdom Rd  Duncanville
# 8            93           52       W  900 W Camp Wisdom Rd  Duncanville
# 9            67           66       W  900 W Camp Wisdom Rd  Duncanville
# 10           79           66       W  900 W Camp Wisdom Rd  Duncanville
# 11           57           51       W  900 W Camp Wisdom Rd  Duncanville
# 12           81           43       W  900 W Camp Wisdom Rd  Duncanville
# 13           61           55       W  900 W Camp Wisdom Rd  Duncanville
# 14           83           49       W  900 W Camp Wisdom Rd  Duncanville
# 15           60           58       L  900 W Camp Wisdom Rd  Duncanville
# 16           54           42       W  900 W Camp Wisdom Rd  Duncanville
# 17           71           55       W  900 W Camp Wisdom Rd  Duncanville
# 18           77           52       W  900 W Camp Wisdom Rd  Duncanville
# 19          106           85       W  900 W Camp Wisdom Rd  Duncanville
# 20           73           31       W  900 W Camp Wisdom Rd  Duncanville
# 21           85           42       W  900 W Camp Wisdom Rd  Duncanville
# 22           76           56       W  900 W Camp Wisdom Rd  Duncanville
# 23           61           42       W  900 W Camp Wisdom Rd  Duncanville
# 24           71           63       W  900 W Camp Wisdom Rd  Duncanville
# 25           91           50       W  900 W Camp Wisdom Rd  Duncanville
# 26           95           50       W  900 W Camp Wisdom Rd  Duncanville
# 27           74           39       W  900 W Camp Wisdom Rd  Duncanville
# 28          105           32       W  900 W Camp Wisdom Rd  Duncanville
# 29           99           63       W  900 W Camp Wisdom Rd  Duncanville
# 30           52           43       W  900 W Camp Wisdom Rd  Duncanville
# 31           48           35       W  900 W Camp Wisdom Rd  Duncanville
# 32           72           59       W  900 W Camp Wisdom Rd  Duncanville
# 33           61           38       W  900 W Camp Wisdom Rd  Duncanville
# 34           50           36       W  900 W Camp Wisdom Rd  Duncanville
# 35           69           49       W  900 W Camp Wisdom Rd  Duncanville
#
#    Team 1 State Team 1 Zipcode            Team 2 Address    Team 2 City  \
# 0            TX          75116            11850 Broadway       Pearland
# 1            TX          75116  200 East Wintergreen Rd.      Lancaster
# 2            TX          75116    3606 S Westmoreland Rd         Dallas
# 3            TX          75116            375 Holt Rd NE       Marietta
# 4            TX          75116           1820 Rimpau Ave         Corona
# 5            TX          75116    20801 West Rinaldi St.     Chatsworth
# 6            TX          75116            16061 Colt Rd.         Frisco
# 7            TX          75116            4100 Bronco Ln        Zachary
# 8            TX          75116         3059 Higgins Blvd    New Orleans
# 9            TX          75116              17235 7Th St      Montverde
# 10           TX          75116        510 North 600 East  American Fork
# 11           TX          75116              600 Eagle Dr         DeSoto
# 12           TX          75116          10600 Preston Rd         Dallas
# 13           TX          75116  4501 W Pleasant Ridge Rd      Arlington
# 14           TX          75116          7700 S Watson Rd      Arlington
# 15           TX          75116       1250 W Belt Line Rd     Richardson
# 16           TX          75116              8200 Mars Dr           Waco
# 17           TX          75116         101 N Day Miar Rd      Mansfield
# 18           TX          75116           1000 Butcher RD     Waxahachie
# 19           TX          75116          1 Longhorn Blvd.     Cedar Hill
# 20           TX          75116           3001 E Broad St      Mansfield
# 21           TX          75116            2020 N 42Nd St           Waco
# 22           TX          75116              600 Eagle Dr         DeSoto
# 23           TX          75116              8200 Mars Dr           Waco
# 24           TX          75116         101 N Day Miar Rd      Mansfield
# 25           TX          75116           1000 Butcher RD     Waxahachie
# 26           TX          75116          1 Longhorn Blvd.     Cedar Hill
# 27           TX          75116           3001 E Broad St      Mansfield
# 28           TX          75116            2020 N 42Nd St           Waco
# 29           TX          75116     3302 S Clear Creek Rd        Killeen
# 30           TX          75116              801 Laurence       Rockwall
# 31           TX          75116              600 Eagle Dr         DeSoto
# 32           TX          75116              10700 Fry Rd        Houston
# 33           TX          75116         310 S Garland Ave        Garland
# 34           TX          75116   13300 Will Clayton Pkwy         Humble
# 35           TX          75116    1400 Wilson Creek Pkwy       McKinney
#
#    Team 2 State Team 2 Zipcode
# 0            TX          77584
# 1            TX          75146
# 2            TX          75233
# 3            GA          30068
# 4            CA          92881
# 5            CA          91311
# 6            TX          75035
# 7            LA          70791
# 8            LA          70126
# 9            FL          34756
# 10           UT          84003
# 11           TX          75115
# 12           TX          75230
# 13           TX          76016
# 14           TX          76002
# 15           TX          75080
# 16           TX          76712
# 17           TX          76063
# 18           TX          75165
# 19           TX          75106
# 20           TX          76063
# 21           TX          76710
# 22           TX          75115
# 23           TX          76712
# 24           TX          76063
# 25           TX          75165
# 26           TX          75106
# 27           TX          76063
# 28           TX          76710
# 29           TX          76549
# 30           TX          75032
# 31           TX          75115
# 32           TX          77433
# 33           TX          75040
# 34           TX          77346
# 35           TX          75069

# %%
school_dict = {'Duncanville': '/tx/duncanville/duncanville-panthers-and-pantherettes/basketball/21-22/schedule/',
 'Richardson': '/tx/richardson/richardson-eagles/basketball/21-22/schedule/',
 'McKinney': '/tx/mckinney/mckinney-lions/basketball/21-22/schedule/',
 'Mansfield Timberview (Arlington)': '/tx/arlington/mansfield-timberview-wolves/basketball/21-22/schedule/',
 'Guyer (Denton)': '/tx/denton/guyer-wildcats/basketball/21-22/schedule/',
 'Beaumont United (Beaumont)': '/tx/beaumont/beaumont-united-timberwolves/basketball/21-22/schedule/',
 'Plano': '/tx/plano/plano-wildcats/basketball/21-22/schedule/',
 'Westlake (Austin)': '/tx/austin/westlake-chaparrals/basketball/21-22/schedule/',
 'Atascocita (Humble)': '/tx/humble/atascocita-eagles/basketball/21-22/schedule/',
 'Oak Cliff Faith Family Academy (Dallas)': '/tx/dallas/oak-cliff-faith-family-academy-eagles/basketball/21-22/schedule/'}

# %%
grand_df = pd.DataFrame()
for school, url in school_dict.items():
    print(school, url)
    school_url = f'https://www.maxpreps.com{url}'
    print(school_url)
    response = requests.get(school_url).text
    soup = BeautifulSoup(response, 'lxml')
    table = soup.find('table')
    data = pd.read_html(str(table))[0]
    data = data.drop('Game Info', axis = 1)
    data['Team 1'] = school
    data['Team 1 Location'] = extractLocation(url)
    data['Team 1 Address'] = extractAddress(url)
    data['Team 1 City'] = splitLocation(data['Team 1 Location'])[0]
    data['Team 1 State'] = splitLocation(data['Team 1 Location'])[1]
    data['Team 1 Zipcode'] = splitLocation(data['Team 1 Location'])[2]
    data['Venue'] = gameInfo(data['Opponent'])[0].apply(cleanVenueType)
    data['Team 2'] = gameInfo(data['Opponent'])[1]
    data['Game Type'] = gameInfo(data['Opponent'])[2].apply(cleanGameType)
    data['Outcome'] = scoreInfo(data['Result'])[0]
    data['Team 1 Score'] = scoreInfo(data['Result'])[1]
    data['Team 2 Score'] = scoreInfo(data['Result'])[2]
    data = data.drop(['Opponent', 'Result', 'Team 1 Location'], axis = 1)
    
    grand_df = pd.concat([grand_df, data], ignore_index = True)
# Out:
# Duncanville /tx/duncanville/duncanville-panthers-and-pantherettes/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/duncanville/duncanville-panthers-and-pantherettes/basketball/21-22/schedule/
# Richardson /tx/richardson/richardson-eagles/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/richardson/richardson-eagles/basketball/21-22/schedule/
# McKinney /tx/mckinney/mckinney-lions/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/mckinney/mckinney-lions/basketball/21-22/schedule/
# Mansfield Timberview (Arlington) /tx/arlington/mansfield-timberview-wolves/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/arlington/mansfield-timberview-wolves/basketball/21-22/schedule/
# Guyer (Denton) /tx/denton/guyer-wildcats/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/denton/guyer-wildcats/basketball/21-22/schedule/
# Beaumont United (Beaumont) /tx/beaumont/beaumont-united-timberwolves/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/beaumont/beaumont-united-timberwolves/basketball/21-22/schedule/
# Plano /tx/plano/plano-wildcats/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/plano/plano-wildcats/basketball/21-22/schedule/
# Westlake (Austin) /tx/austin/westlake-chaparrals/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/austin/westlake-chaparrals/basketball/21-22/schedule/
# Atascocita (Humble) /tx/humble/atascocita-eagles/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/humble/atascocita-eagles/basketball/21-22/schedule/
# Oak Cliff Faith Family Academy (Dallas) /tx/dallas/oak-cliff-faith-family-academy-eagles/basketball/21-22/schedule/
# https://www.maxpreps.com/tx/dallas/oak-cliff-faith-family-academy-eagles/basketball/21-22/schedule/

# %%
grand_df
# Out:
#       Date                                   Team 1        Team 1 Address  \
# 0    11/12                              Duncanville  900 W Camp Wisdom Rd
# 1    11/13                              Duncanville  900 W Camp Wisdom Rd
# 2    11/20                              Duncanville  900 W Camp Wisdom Rd
# 3    11/24                              Duncanville  900 W Camp Wisdom Rd
# 4    11/26                              Duncanville  900 W Camp Wisdom Rd
# ..     ...                                      ...                   ...
# 379    3/1  Oak Cliff Faith Family Academy (Dallas)      300 W Kiest Blvd
# 380    3/4  Oak Cliff Faith Family Academy (Dallas)      300 W Kiest Blvd
# 381    3/5  Oak Cliff Faith Family Academy (Dallas)      300 W Kiest Blvd
# 382   3/11  Oak Cliff Faith Family Academy (Dallas)      300 W Kiest Blvd
# 383   3/12  Oak Cliff Faith Family Academy (Dallas)      300 W Kiest Blvd
#
#      Team 1 City Team 1 State Team 1 Zipcode Venue        Team 2  \
# 0    Duncanville           TX          75116     H  Shadow Creek
# 1    Duncanville           TX          75116     H     Lancaster
# 2    Duncanville           TX          75116     H       Kimball
# 3    Duncanville           TX          75116     H       Wheeler
# 4    Duncanville           TX          75116     H    Centennial
# ..           ...          ...            ...   ...           ...
# 379       Dallas           TX          75224     H   Van Alstyne
# 380       Dallas           TX          75224     H       Kaufman
# 381       Dallas           TX          75224     H        Carter
# 382       Dallas           TX          75224     H       Silsbee
# 383       Dallas           TX          75224     H       Hirschi
#
#           Game Type Outcome Team 1 Score Team 2 Score
# 0    Regular Season       W           89           38
# 1    Regular Season       W          102           59
# 2    Regular Season       W           84           82
# 3    Regular Season       W           80           58
# 4    Regular Season       W           75           70
# ..              ...     ...          ...          ...
# 379  Regular Season       W           91           45
# 380         Playoff       W           41           36
# 381         Playoff       W           70           56
# 382  Regular Season       W           70           62
# 383         Playoff       W           76           50
#
# [384 rows x 12 columns]
